# %%
#!/usr/bin/python

""" 
    Starter code for exploring the Enron dataset (emails + finances);
    loads up the dataset (pickled dict of dicts).

    The dataset has the form:
    enron_data["LASTNAME FIRSTNAME MIDDLEINITIAL"] = { features_dict }

    {features_dict} is a dictionary of features associated with that person.
    You should explore features_dict as part of the mini-project,
    but here's an example to get you started:

    enron_data["SKILLING JEFFREY K"]["bonus"] = 5600000
    
"""

import pickle


enron_data = pickle.load(open("../final_project/final_project_dataset.pkl", "r"))

# %%
import pandas

len(enron_data)
# print enron_data
df=pandas.DataFrame(enron_data)
# print (df)
df.head()
df
# Out:
#                                    ALLEN PHILLIP K BADUM JAMES P  \
# bonus                                      4175000           NaN
# deferral_payments                          2869717        178980
# deferred_income                           -3081055           NaN
# director_fees                                  NaN           NaN
# email_address              phillip.allen@enron.com           NaN
# exercised_stock_options                    1729541        257817
# expenses                                     13868          3486
# from_messages                                 2195           NaN
# from_poi_to_this_person                         47           NaN
# from_this_person_to_poi                         65           NaN
# loan_advances                                  NaN           NaN
# long_term_incentive                         304805           NaN
# other                                          152           NaN
# ...

# %%
c=[df.loc["exercised_stock_options"][]]
print max(c)
print min(c)
# Out:
# 257817
# 257817

# %%
c=0
for feature in df:
    if df[feature]['poi']==1:
        c+=1
print c
# Out:
# 18

# %%
enron_poi = open("../final_project/poi_names.txt", "r")
lines = enron_poi.readlines()
print lines
len(lines)

# dp=pandas.DataFrame(enron_poi)
# dp.head()
# Out:
# ['http://usatoday30.usatoday.com/money/industries/energy/2005-12-28-enron-participants_x.htm\n', '\n', '(y) Lay, Kenneth\n', '(y) Skilling, Jeffrey\n', '(n) Howard, Kevin\n', '(n) Krautz, Michael\n', '(n) Yeager, Scott\n', '(n) Hirko, Joseph\n', '(n) Shelby, Rex\n', '(n) Bermingham, David\n', '(n) Darby, Giles\n', '(n) Mulgrew, Gary\n', '(n) Bayley, Daniel\n', '(n) Brown, James\n', '(n) Furst, Robert\n', '(n) Fuhs, William\n', '(n) Causey, Richard\n', '(n) Calger, Christopher\n', '(n) DeSpain, Timothy\n', '(n) Hannon, Kevin\n', '(n) Koenig, Mark\n', '(y) Forney, John\n', '(n) Rice, Kenneth\n', '(n) Rieker, Paula\n', '(n) Fastow, Lea\n', '(n) Fastow, Andrew\n', '(y) Delainey, David\n', '(n) Glisan, Ben\n', '(n) Richter, Jeffrey\n', '(n) Lawyer, Larry\n', '(n) Belden, Timothy\n', '(n) Kopper, Michael\n', '(n) Duncan, David\n', '(n) Bowen, Raymond\n', '(n) Colwell, Wesley\n', '(n) Boyle, Dan\n', '(n) Loehr, Christopher\n']
# 37

# %%
list(df)
df["PRENTICE JAMES"]["total_stock_value"]
# Out:
# 1095040

# %%
df["COLWELL WESLEY"]["from_this_person_to_poi"]
# Out:
# 11

# %%
list(df)
df["SKILLING JEFFREY K"]["exercised_stock_options"]
# Out:
# 19250000

# %%
print df["SKILLING JEFFREY K"]["total_payments"]
print df["LAY KENNETH L"]["total_payments"]
print df["FASTOW ANDREW S"]["total_payments"]
# Out:
# 8682716
# 103559793
# 2424083

# %%
c=0
for feature in df:
    if df[feature]['salary'] != 'NaN':
        c+=1
print c

e=0
for feature in df:
    if df[feature]['email_address'] != 'NaN':
        e+=1
print e
# Out:
# 95
# 111

# %%
t=0
for feature in df:
    if df[feature]['total_payments'] == 'NaN':
        t+=1
print t

t/146.0 * 100
# Out:
# 21
# 14.383561643835616

# %%
p=0
pt=0
for feature in df:
    if df[feature]['poi'] == True:
        p+=1
        if df[feature]['total_payments'] == 'NaN':
            pt+=1
print p
print pt
# Out:
# 18
# 0

# %%
pl=list(df)

# %%
enron_poi = open("../final_project/poi_names.txt", "r")
lines = enron_poi.readlines()


for index in range(len(lines)):
    if lines[index].find('(y)') != -1:
        print lines[index]
# Out:
# (y) Lay, Kenneth
#
# (y) Skilling, Jeffrey
#
# (y) Forney, John
#
# (y) Delainey, David

# %%
#'LAY KENNETH L',  'FUGH JOHN L', 'SKILLING JEFFREY K','DELAINEY DAVID W'

print df["SKILLING JEFFREY K"]["total_payments"]
print df["LAY KENNETH L"]["total_payments"]
print df["FASTOW ANDREW S"]["total_payments"]
# Out:
# 8682716
# 103559793
# 2424083

# %%
import pandas

len(enron_data)
# print enron_data
df=pandas.DataFrame(enron_data)
# print (df)
df.head()
# Out:
#                            ALLEN PHILLIP K BADUM JAMES P  \
# bonus                              4175000           NaN
# deferral_payments                  2869717        178980
# deferred_income                   -3081055           NaN
# director_fees                          NaN           NaN
# email_address      phillip.allen@enron.com           NaN
#
#                            BANNANTINE JAMES M BAXTER JOHN C  \
# bonus                                     NaN       1200000
# deferral_payments                         NaN       1295738
# deferred_income                         -5104      -1386055
# director_fees                             NaN           NaN
# email_address      james.bannantine@enron.com           NaN
#
#                         BAY FRANKLIN R BAZELIDES PHILIP J  \
# bonus                           400000                NaN
# deferral_payments               260455             684694
# deferred_income                -201641                NaN
# ...

# %%
c=[]
for feature in df:
    if df[feature]['salary'] != "NaN":
        c.append(df[feature]['salary'])

print max(c)
print min(c)
# Out:
# 26704229
# 477

# %%
data_dict = pickle.load( open("../final_project/final_project_dataset.pkl", "r") )

# %%
e=[]
e.append([i["exercised_stock_options"] for i in data_dict_with_outlier.iterkeys() if not i["exercised_stock_options"] == "NaN"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-da5341025d9c> in <module>()
#       1 e=[]
# ----> 2 e.append([i["exercised_stock_options"] for i in data_dict_with_outlier.iterkeys() if not i["exercised_stock_options"] == "NaN"])
#
# TypeError: string indices must be integers, not str

# %%
exercised_stock_options = [item["exercised_stock_options"] for k, item in data_dict.iteritems() if not item["exercised_stock_options"] == "NaN"]                                                                                                                                
print "min is %s" % min(exercised_stock_options)
print "max is %s" % max(exercised_stock_options)
# Out:
# min is 3285
# max is 311764000
